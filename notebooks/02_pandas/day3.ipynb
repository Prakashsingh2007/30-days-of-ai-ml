# %%
import pandas as pd

df = pd.read_csv("students.csv")
print(df)
# Out:
#        Name  Age  Marks Branch  passed
# 0     Aarav   18     95    CSE    True
# 1    Vivaan   19     82     IT    True
# 2    Aditya   18     76    ECE    True
# 3   Krishna   20     45    CSE    True
# 4     Rohan   19     67     ME    True
# 5     Priya   18     91    CSE    True
# 6    Ananya   19     88     IT    True
# 7     Sneha   20     39    ECE   False
# 8     Kavya   18     58    EEE    True
# 9    Ishita   19     73     ME    True
# 10    Rahul   20     99    CSE    True
# 11     Amit   21     25     IT   False
# 12     Neha   18     61    ECE    True
# 13    Pooja   19     84    EEE    True
# 14    Karan   20     77     ME    True
# 15    Arjun   18     55    CSE    True
# 16    Meera   19     93     IT    True
# 17     Diya   18     48    ECE    True
# 18    Sahil   20     35    EEE   False
# 19   Nikhil   21     80     ME    True

# %%
print(df.Age)
# Out:
# 0     18
# 1     19
# 2     18
# 3     20
# 4     19
# 5     18
# 6     19
# 7     20
# 8     18
# 9     19
# 10    20
# 11    21
# 12    18
# 13    19
# 14    20
# 15    18
# 16    19
# 17    18
# 18    20
# 19    21
# Name: Age, dtype: int64

# %%
n = df[df.Marks>= 90]
print(n)
# Out:
#      Name  Age  Marks Branch  passed
# 0   Aarav   18     95    CSE    True
# 5   Priya   18     91    CSE    True
# 10  Rahul   20     99    CSE    True
# 16  Meera   19     93     IT    True

# %%
df["bonus"] = df['Marks'] * 0.1
print(df)
# Out:
#        Name  Age  Marks Branch  passed  bonus
# 0     Aarav   18     95    CSE    True    9.5
# 1    Vivaan   19     82     IT    True    8.2
# 2    Aditya   18     76    ECE    True    7.6
# 3   Krishna   20     45    CSE    True    4.5
# 4     Rohan   19     67     ME    True    6.7
# 5     Priya   18     91    CSE    True    9.1
# 6    Ananya   19     88     IT    True    8.8
# 7     Sneha   20     39    ECE   False    3.9
# 8     Kavya   18     58    EEE    True    5.8
# 9    Ishita   19     73     ME    True    7.3
# 10    Rahul   20     99    CSE    True    9.9
# 11     Amit   21     25     IT   False    2.5
# 12     Neha   18     61    ECE    True    6.1
# 13    Pooja   19     84    EEE    True    8.4
# 14    Karan   20     77     ME    True    7.7
# 15    Arjun   18     55    CSE    True    5.5
# 16    Meera   19     93     IT    True    9.3
# 17     Diya   18     48    ECE    True    4.8
# 18    Sahil   20     35    EEE   False    3.5
# ...

# %%
sort = df.sort_values(by='bonus', ascending=False)
print(sort)
# Out:
#        Name  Age  Marks Branch  passed  bonus
# 10    Rahul   20     99    CSE    True    9.9
# 0     Aarav   18     95    CSE    True    9.5
# 16    Meera   19     93     IT    True    9.3
# 5     Priya   18     91    CSE    True    9.1
# 6    Ananya   19     88     IT    True    8.8
# 13    Pooja   19     84    EEE    True    8.4
# 19   Nikhil   21     80     ME    True    8.0
# 14    Karan   20     77     ME    True    7.7
# 2    Aditya   18     76    ECE    True    7.6
# 9    Ishita   19     73     ME    True    7.3
# 4     Rohan   19     67     ME    True    6.7
# 12     Neha   18     61    ECE    True    6.1
# 8     Kavya   18     58    EEE    True    5.8
# 15    Arjun   18     55    CSE    True    5.5
# 17     Diya   18     48    ECE    True    4.8
# 3   Krishna   20     45    CSE    True    4.5
# 7     Sneha   20     39    ECE   False    3.9
# 18    Sahil   20     35    EEE   False    3.5
# 11     Amit   21     25     IT   False    2.5
# ...

# %%
df.at[1, 'bonus'] = None
n = df['bonus'].mean()
print(n)
# Out:
# 6.78421052631579
#        Name  Age  Marks Branch  passed  bonus
# 0     Aarav   18     95    CSE    True    9.5
# 1    Vivaan   19     82     IT    True    NaN
# 2    Aditya   18     76    ECE    True    7.6
# 3   Krishna   20     45    CSE    True    4.5
# 4     Rohan   19     67     ME    True    6.7
# 5     Priya   18     91    CSE    True    9.1
# 6    Ananya   19     88     IT    True    8.8
# 7     Sneha   20     39    ECE   False    3.9
# 8     Kavya   18     58    EEE    True    5.8
# 9    Ishita   19     73     ME    True    7.3
# 10    Rahul   20     99    CSE    True    9.9
# 11     Amit   21     25     IT   False    2.5
# 12     Neha   18     61    ECE    True    6.1
# 13    Pooja   19     84    EEE    True    8.4
# 14    Karan   20     77     ME    True    7.7
# 15    Arjun   18     55    CSE    True    5.5
# 16    Meera   19     93     IT    True    9.3
# 17     Diya   18     48    ECE    True    4.8
# 18    Sahil   20     35    EEE   False    3.5
# ...

# %%
df['bonus'] = df['bonus'].fillna(n)
print(df)
# Out:
#        Name  Age  Marks Branch  passed     bonus
# 0     Aarav   18     95    CSE    True  9.500000
# 1    Vivaan   19     82     IT    True  6.784211
# 2    Aditya   18     76    ECE    True  7.600000
# 3   Krishna   20     45    CSE    True  4.500000
# 4     Rohan   19     67     ME    True  6.700000
# 5     Priya   18     91    CSE    True  9.100000
# 6    Ananya   19     88     IT    True  8.800000
# 7     Sneha   20     39    ECE   False  3.900000
# 8     Kavya   18     58    EEE    True  5.800000
# 9    Ishita   19     73     ME    True  7.300000
# 10    Rahul   20     99    CSE    True  9.900000
# 11     Amit   21     25     IT   False  2.500000
# 12     Neha   18     61    ECE    True  6.100000
# 13    Pooja   19     84    EEE    True  8.400000
# 14    Karan   20     77     ME    True  7.700000
# 15    Arjun   18     55    CSE    True  5.500000
# 16    Meera   19     93     IT    True  9.300000
# 17     Diya   18     48    ECE    True  4.800000
# ...
