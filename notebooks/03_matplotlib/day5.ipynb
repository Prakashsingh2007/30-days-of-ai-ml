# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "StudyHours": np.random.randint(1,10,100),
    "Marks": np.random.randint(30,100,100),
    "Attendance": np.random.randint(60,100,100),
    "Branch": np.random.choice(["CSE","AI","ECE"],100)
})
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Marks"])
plt.show()
sns.boxplot(y=df["Marks"])
plt.show()
