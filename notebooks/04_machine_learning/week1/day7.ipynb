# %%
import pandas as pd
data = {
    "Hours": [2, 4, 6, 8, 10],
    "Marks": [30, 50, 70, 90, 100]
}

df = pd.DataFrame(data)
df
# Out:
#    Hours  Marks
# 0      2     30
# 1      4     50
# 2      6     70
# 3      8     90
# 4     10    100

# %%
X = df[["Hours"]]

y = df["Marks"]
print(X)
print(end="\n")
print(y)
# Out:
#    Hours
# 0      2
# 1      4
# 2      6
# 3      8
# 4     10
#
# 0     30
# 1     50
# 2     70
# 3     90
# 4    100
# Name: Marks, dtype: int64
