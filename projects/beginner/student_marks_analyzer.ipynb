# %%
import numpy as np
n1 = np.random.randint(1, 100, 10)
print(n1)
# Out:
# [41 40 51  2 16 65 32 35 68 56]

# %%
n1.sum()
n1.mean()
n1.max()
n1.min()
print(n1.sum())
print(n1.mean())
print(n1.max())
print(n1.min())
# Out:
# 556
# 55.6
# 95
# 17

# %%
n2 = n1 + 5
print(n2)
# Out:
# [ 33  40  33  85  97  22  73  89  34 100]
