# %%
import pandas as pd

students = {
    "Name": [
        "Aarav", "Vivaan", "Aditya", "Krishna", "Rohan",
        "Priya", "Ananya", "Sneha", "Kavya", "Ishita",
        "Rahul", "Amit", "Neha", "Pooja", "Karan",
        "Arjun", "Meera", "Diya", "Sahil", "Nikhil"
    ],

    "Age": [
        18,19,18,20,19,
        18,19,20,18,19,
        20,21,18,19,20,
        18,19,18,20,21
    ],

    "Marks": [
        95,82,76,45,67,
        91,88,39,58,73,
        99,25,61,84,77,
        55,93,48,35,80
    ],

    "Branch": [
        "CSE","IT","ECE","CSE","ME",
        "CSE","IT","ECE","EEE","ME",
        "CSE","IT","ECE","EEE","ME",
        "CSE","IT","ECE","EEE","ME"
    ]
}

df = pd.DataFrame(students)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#        Name  Age  Marks Branch
# 0     Aarav   18     95    CSE
# 1    Vivaan   19     82     IT
# 2    Aditya   18     76    ECE
# 3   Krishna   20     45    CSE
# 4     Rohan   19     67     ME
# 5     Priya   18     91    CSE
# 6    Ananya   19     88     IT
# 7     Sneha   20     39    ECE
# 8     Kavya   18     58    EEE
# 9    Ishita   19     73     ME
# 10    Rahul   20     99    CSE
# 11     Amit   21     25     IT
# 12     Neha   18     61    ECE
# 13    Pooja   19     84    EEE
# 14    Karan   20     77     ME
# 15    Arjun   18     55    CSE
# 16    Meera   19     93     IT
# 17     Diya   18     48    ECE
# 18    Sahil   20     35    EEE
# 19   Nikhil   21     80     ME

# %%
df1 = df.head()
print("\nFirst 10 rows of the DataFrame:")
print(df1)
# Out:
# First 10 rows of the DataFrame:
#       Name  Age  Marks Branch
# 0    Aarav   18     95    CSE
# 1   Vivaan   19     82     IT
# 2   Aditya   18     76    ECE
# 3  Krishna   20     45    CSE
# 4    Rohan   19     67     ME

# %%
df2 = df.shape

print(df2)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    20 non-null     str
#  1   Age     20 non-null     int64
#  2   Marks   20 non-null     int64
#  3   Branch  20 non-null     str
# dtypes: int64(2), str(2)
# memory usage: 772.0 bytes
# (20, 4)
# None

# %%
df3 = df.info()
print(df3)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    20 non-null     str
#  1   Age     20 non-null     int64
#  2   Marks   20 non-null     int64
#  3   Branch  20 non-null     str
# dtypes: int64(2), str(2)
# memory usage: 772.0 bytes
# None

# %%
n = df.describe()
print(n)
# Out:
#              Age      Marks
# count  20.000000  20.000000
# mean   19.100000  68.550000
# std     1.020836  21.801678
# min    18.000000  25.000000
# 25%    18.000000  53.250000
# 50%    19.000000  74.500000
# 75%    20.000000  85.000000
# max    21.000000  99.000000

# %%
high = df[df['Marks'] == df['Marks'].max() ]
print(high)
min= df[df['Marks'] == df['Marks'].min() ]
print(min)
avg = df['Marks'].mean()
print(avg)
df["passed"] = df['Marks'] >= 40
print(df)
# Out:
#      Name  Age  Marks Branch  passed
# 10  Rahul   20     99    CSE    True
#     Name  Age  Marks Branch  passed
# 11  Amit   21     25     IT   False
# 68.55
#        Name  Age  Marks Branch  passed
# 0     Aarav   18     95    CSE    True
# 1    Vivaan   19     82     IT    True
# 2    Aditya   18     76    ECE    True
# 3   Krishna   20     45    CSE    True
# 4     Rohan   19     67     ME    True
# 5     Priya   18     91    CSE    True
# 6    Ananya   19     88     IT    True
# 7     Sneha   20     39    ECE   False
# 8     Kavya   18     58    EEE    True
# 9    Ishita   19     73     ME    True
# 10    Rahul   20     99    CSE    True
# 11     Amit   21     25     IT   False
# 12     Neha   18     61    ECE    True
# 13    Pooja   19     84    EEE    True
# 14    Karan   20     77     ME    True
# 15    Arjun   18     55    CSE    True
# 16    Meera   19     93     IT    True
# 17     Diya   18     48    ECE    True
# 18    Sahil   20     35    EEE   False
# ...

# %%
n = df[df['Marks'] >= 70]
print(n)
# Out:
#       Name  Age  Marks Branch  passed
# 0    Aarav   18     95    CSE    True
# 1   Vivaan   19     82     IT    True
# 2   Aditya   18     76    ECE    True
# 5    Priya   18     91    CSE    True
# 6   Ananya   19     88     IT    True
# 9   Ishita   19     73     ME    True
# 10   Rahul   20     99    CSE    True
# 13   Pooja   19     84    EEE    True
# 14   Karan   20     77     ME    True
# 16   Meera   19     93     IT    True
# 19  Nikhil   21     80     ME    True

# %%
sort = df.sort_values(by='Marks', ascending=False)
print(sort)
# Out:
#        Name  Age  Marks Branch  passed
# 10    Rahul   20     99    CSE    True
# 0     Aarav   18     95    CSE    True
# 16    Meera   19     93     IT    True
# 5     Priya   18     91    CSE    True
# 6    Ananya   19     88     IT    True
# 13    Pooja   19     84    EEE    True
# 1    Vivaan   19     82     IT    True
# 19   Nikhil   21     80     ME    True
# 14    Karan   20     77     ME    True
# 2    Aditya   18     76    ECE    True
# 9    Ishita   19     73     ME    True
# 4     Rohan   19     67     ME    True
# 12     Neha   18     61    ECE    True
# 8     Kavya   18     58    EEE    True
# 15    Arjun   18     55    CSE    True
# 17     Diya   18     48    ECE    True
# 3   Krishna   20     45    CSE    True
# 7     Sneha   20     39    ECE   False
# 18    Sahil   20     35    EEE   False
# 11     Amit   21     25     IT   False

# %%
df.to_csv('student_report.csv', index=False)
